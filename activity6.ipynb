# %%
import seaborn as sns

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import scipy.stats as sp

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
dengue = pd.read_csv(".//dataset//dengue.csv")

# %%
dengue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Month          1020 non-null   object
#  1   Year           1020 non-null   int64
#  2   Region         1020 non-null   object
#  3   Dengue_Cases   1020 non-null   int64
#  4   Dengue_Deaths  1020 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 40.0+ KB

# %%
dengue['Month'] = dengue["Month"].astype('category')
dengue['Region'] = dengue["Region"].astype('category')
dengue['Year'] = dengue["Year"].astype('category')

# %%
dengue
# Out:
#           Month  Year    Region  Dengue_Cases  Dengue_Deaths
# 0       January  2016  Region I           705              1
# 1      February  2016  Region I           374              0
# 2         March  2016  Region I           276              0
# 3         April  2016  Region I           240              2
# 4           May  2016  Region I           243              1
# ...         ...   ...       ...           ...            ...
# 1015     August  2020     BARMM            91              0
# 1016  September  2020     BARMM            16              8
# 1017    October  2020     BARMM            13              9
# 1018   November  2020     BARMM            15              1
# 1019   December  2020     BARMM            23              0
#
# [1020 rows x 5 columns]

# %%
dengue['Year'].value_counts()
# Out:
# Year
# 2016    204
# 2017    204
# 2018    204
# 2019    204
# 2020    204
# Name: count, dtype: int64

# %%
dengue['Region'].value_counts()
# Out:
# Region
# BARMM          60
# Region V       60
# Region XII     60
# Region XI      60
# Region X       60
# Region VIII    60
# Region VII     60
# Region VI      60
# Region IX      60
# CAR            60
# Region IV-B    60
# Region IV-A    60
# Region III     60
# Region II      60
# Region I       60
# NCR            60
# Region XIII    60
# Name: count, dtype: int64

# %%
dengue['Month'].value_counts()
# Out:
# Month
# April        85
# August       85
# December     85
# February     85
# January      85
# July         85
# June         85
# March        85
# May          85
# November     85
# October      85
# September    85
# Name: count, dtype: int64

# %%
dengue['Dengue_Cases'].value_counts()
# Out:
# Dengue_Cases
# 207     5
# 276     4
# 694     4
# 451     4
# 203     4
#        ..
# 336     1
# 310     1
# 1577    1
# 755     1
# 15      1
# Name: count, Length: 794, dtype: int64

# %%
dengue['Dengue_Deaths'].value_counts()
# Out:
# Dengue_Deaths
# 0      170
# 2      148
# 1      142
# 3      104
# 4       81
#       ...
# 116      1
# 176      1
# 243      1
# 282      1
# 105      1
# Name: count, Length: 68, dtype: int64

# %%
case_2016 = dengue[(dengue['Year'] == 2016)]
case_2016
# Out:
#          Month  Year    Region  Dengue_Cases  Dengue_Deaths
# 0      January  2016  Region I           705              1
# 1     February  2016  Region I           374              0
# 2        March  2016  Region I           276              0
# 3        April  2016  Region I           240              2
# 4          May  2016  Region I           243              1
# ..         ...   ...       ...           ...            ...
# 967     August  2016     BARMM           327              2
# 968  September  2016     BARMM           124            105
# 969    October  2016     BARMM            82            109
# 970   November  2016     BARMM           143              1
# 971   December  2016     BARMM           162              2
#
# [204 rows x 5 columns]

# %%
dengue["Dengue_Cases"].corr(dengue["Dengue_Deaths"])
# Out:
# 0.03832213720419488

# %% [markdown]
# <h1>Question 1: Which Year has the highest Dengue Cases?</h1>

# %%
dengue_year = dengue.groupby('Year')['Dengue_Cases'].sum()
dengue_year.plot(kind='bar')
plt.ylabel('Dengue Cases')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# <h2>Insight 1: 2019 is the year that has the highest dengue cases.</h2>

# %% [markdown]
# <h1>Question 2: Which Year has the lowest Dengue Cases?</h1>

# %%
dengue_year = dengue.groupby('Year')['Dengue_Cases'].sum()
dengue_year.plot(kind='bar')
plt.ylabel('Dengue Cases')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# <h2>Insight 2: 2020 is the year that has the lowest dengue cases.</h2>

# %% [markdown]
# <h1>Question 3: Which Year has the highest Dengue Deaths?</h1>

# %%
dengue_year = dengue.groupby('Year')['Dengue_Deaths'].sum()
dengue_year.plot(kind='bar')
plt.ylabel('Dengue Deaths')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# <h2>Insight 3: 2016 is the year that has the highest dengue deaths.</h2>

# %% [markdown]
# <h1>Question 4: Which Year has the lowest Dengue Deaths?</h1>

# %%
dengue_year = dengue.groupby('Year')['Dengue_Deaths'].sum()
dengue_year.plot(kind='bar')
plt.ylabel('Dengue Deaths')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
dengue_year = dengue.groupby('Year')['Dengue_Deaths'].sum()
dengue_year
# Out:
# Year
# 2016    8127
# 2017    4563
# 2018    1226
# 2019    1733
# 2020    1195
# Name: Dengue_Deaths, dtype: int64

# %% [markdown]
# <h2>Insight 4: 2020 is the year that has the lowest dengue deaths.</h2>

# %% [markdown]
# <h1>Question 5: Which Month has the highest Dengue Cases?</h1>

# %%
dengue_month = dengue.groupby('Month')['Dengue_Cases'].sum()
dengue_month.plot(kind='bar')
plt.ylabel('Dengue Cases')
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# <h2>Insight 5: August is the month that has the highest dengue cases.</h2>

# %% [markdown]
# <h1>Question 6: Which Month has the lowest Dengue Cases?</h1>

# %%
dengue_month = dengue.groupby('Month')['Dengue_Cases'].sum()
dengue_month.plot(kind='bar')
plt.ylabel('Dengue Cases')
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %%
dengue_month = dengue.groupby('Month')['Dengue_Cases'].sum()
dengue_month.sort_values()
# Out:
# Month
# May           32387
# April         32508
# March         57576
# June          58110
# February      77801
# January       84328
# December      88431
# November      94900
# October      117645
# July         138242
# September    177943
# August       187554
# Name: Dengue_Cases, dtype: int64

# %% [markdown]
# <h2>Insight 6: May is the month that has the lowest dengue cases.</h2>

# %% [markdown]
# <h1>Question 7: Which Month has the highest Dengue Deaths?</h1>

# %%
dengue_month = dengue.groupby('Month')['Dengue_Deaths'].sum()
dengue_month.plot(kind='bar')
plt.ylabel('Dengue Deaths')
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# <h2>Insight 7: October is the month that has the highest dengue deaths</h2>

# %% [markdown]
# <h1>Question 8: Which Month has the lowest Dengue Deaths?</h1>

# %%
dengue_month = dengue.groupby('Month')['Dengue_Deaths'].sum()
dengue_month.plot(kind='bar')
plt.ylabel('Dengue Deaths')
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %%
dengue_month = dengue.groupby('Month')['Dengue_Deaths'].sum()
dengue_month.sort_values()
# Out:
# Month
# May           162
# April         200
# March         291
# February      315
# June          322
# January       394
# December      404
# July          611
# November      613
# August        714
# September    6148
# October      6670
# Name: Dengue_Deaths, dtype: int64

# %% [markdown]
# <h2>Insight 8: May is the month that has the lowest dengue deaths</h2>

# %% [markdown]
# <h1>Question 9: Which Region has the highest Dengue Cases?</h1>

# %%
dengue_region = dengue.groupby('Region')['Dengue_Cases'].sum()
dengue_region.plot(kind='bar')
plt.ylabel('Dengue Cases')
plt.xlabel('Region')
# Out:
# Text(0.5, 0, 'Region')

# %% [markdown]
# <h2>Insight 9: Region IV-A is the region that has the highest dengue cases</h2>

# %% [markdown]
# <h1>Question 10: Which Region has the lowest Dengue Cases?</h1>

# %%
dengue_region = dengue.groupby('Region')['Dengue_Cases'].sum()
dengue_region.plot(kind='bar')
plt.ylabel('Dengue Cases')
plt.xlabel('Region')
# Out:
# Text(0.5, 0, 'Region')

# %%
dengue_month = dengue.groupby('Region')['Dengue_Cases'].sum()
dengue_month.sort_values()
# Out:
# Region
# BARMM           11537
# Region V        22167
# CAR             30582
# Region IV-B     30849
# Region XI       32522
# Region XIII     35293
# Region II       45141
# Region IX       47781
# Region VIII     51983
# Region I        59066
# Region XII      59802
# Region X        82437
# Region VII     110683
# NCR            115966
# Region VI      117523
# Region III     131064
# Region IV-A    163029
# Name: Dengue_Cases, dtype: int64

# %% [markdown]
# <h2>Insight 10: BARMM is the region that has the lowest dengue cases</h2>

# %% [markdown]
# <h1>Question 11: Which Region has the highest Dengue Deaths?</h1>

# %%
dengue_region = dengue.groupby('Region')['Dengue_Deaths'].sum()
dengue_region.plot(kind='bar')
plt.ylabel('Dengue Deaths')
plt.xlabel('Region')
# Out:
# Text(0.5, 0, 'Region')

# %%
dengue_month = dengue.groupby('Region')['Dengue_Deaths'].sum()
dengue_month.sort_values()
# Out:
# Region
# Region IV-B     130
# Region I        157
# Region V        185
# Region II       193
# BARMM           332
# Region XI       385
# Region III      482
# Region IX       532
# Region VIII     585
# Region IV-A     652
# Region X        848
# Region XIII     966
# CAR            1008
# Region VII     1760
# Region VI      1825
# Region XII     2796
# NCR            4008
# Name: Dengue_Deaths, dtype: int64

# %% [markdown]
# <h2>Insight 11: NCR is the region that has the highest dengue deaths</h2>

# %% [markdown]
# <h1>Question 12: Which Region has the lowest Dengue Deaths?</h1>

# %%
dengue_region = dengue.groupby('Region')['Dengue_Deaths'].sum()
dengue_region.plot(kind='bar')
plt.ylabel('Dengue Deaths')
plt.xlabel('Region')
# Out:
# Text(0.5, 0, 'Region')

# %%
dengue_month = dengue.groupby('Region')['Dengue_Deaths'].sum()
dengue_month.sort_values()
# Out:
# Region
# Region IV-B     130
# Region I        157
# Region V        185
# Region II       193
# BARMM           332
# Region XI       385
# Region III      482
# Region IX       532
# Region VIII     585
# Region IV-A     652
# Region X        848
# Region XIII     966
# CAR            1008
# Region VII     1760
# Region VI      1825
# Region XII     2796
# NCR            4008
# Name: Dengue_Deaths, dtype: int64

# %% [markdown]
# <h2>Insight 12: Region IV-B is the region that has the lowest dengue deaths</h2>

# %% [markdown]
# <h1>Question 13: What is the correlation between dengue cases and dengue deaths?</h1>

# %%
dengue["Dengue_Cases"].corr(dengue["Dengue_Deaths"])
# Out:
# 0.03832213720419488

# %%
dengue["Dengue_Deaths"].corr(dengue["Dengue_Cases"])
# Out:
# 0.03832213720419488

# %% [markdown]
# <h2>Insight 13: Since the value of correlation is 0.03, There is no correlation between dengue cases and dengue deaths.</h2>

# %% [markdown]
# <h1>Question 14: What is the ranking of the year based on the amount of dengue cases</h1>

# %%
dengue_year = dengue.groupby('Year')['Dengue_Cases'].sum().sort_values(ascending=False)
dengue_year.plot(kind='bar')
plt.xlabel('Year')
plt.ylabel('Dengue Cases')
# Out:
# Text(0, 0.5, 'Dengue Cases')

# %%
dengue_year = dengue.groupby('Year')['Dengue_Cases'].sum().sort_values(ascending=False)
dengue_year
# Out:
# Year
# 2019    441902
# 2018    250783
# 2016    209544
# 2017    154155
# 2020     91041
# Name: Dengue_Cases, dtype: int64

# %% [markdown]
# <h2>Insight 14: Descending year based on dengue cases: 2019, 2018, 2016, 2017, 2020</h2>

# %% [markdown]
# <h1>Question 15: What is the ranking of the year based on the amount of dengue deaths</h1>

# %%
dengue_year = dengue.groupby('Year')['Dengue_Deaths'].sum().sort_values(ascending=False)
dengue_year.plot(kind='bar')
plt.xlabel('Year')
plt.ylabel('Dengue Deaths')
# Out:
# Text(0, 0.5, 'Dengue Deaths')

# %% [markdown]
# <h2>Insight 15: Descending year based on dengue deaths: 2016, 2017, 2019, 2018, 2020</h2>

# %% [markdown]
# <h1>Question 16: Which five regions have the highest dengue cases</h1>

# %%
dengue_region = dengue.groupby('Region')['Dengue_Cases'].sum().sort_values(ascending=False)
dengue_region.plot(kind='bar')
plt.xlabel('Region')
plt.ylabel('Dengue Cases')
# Out:
# Text(0, 0.5, 'Dengue Cases')

# %%
dengue_region = dengue.groupby('Region')['Dengue_Cases'].sum().sort_values(ascending=False)
dengue_region.head()
# Out:
# Region
# Region IV-A    163029
# Region III     131064
# Region VI      117523
# NCR            115966
# Region VII     110683
# Name: Dengue_Cases, dtype: int64

# %% [markdown]
# <h2>Insight 16: The top 5 region with the highest dengue cases are the following in order: Region IV-A, Region III, Region VI, NCR, and Region VII</h2>

# %% [markdown]
# <h1>Question 17: Which five regions have the lowest dengue cases</h1>

# %%
dengue_region = dengue.groupby('Region')['Dengue_Cases'].sum().sort_values(ascending=True)
dengue_region.plot(kind='bar')
plt.xlabel('Region')
plt.ylabel('Dengue Cases')
# Out:
# Text(0, 0.5, 'Dengue Cases')

# %%
dengue_region = dengue.groupby('Region')['Dengue_Cases'].sum().sort_values(ascending=True)
dengue_region.head()
# Out:
# Region
# BARMM          11537
# Region V       22167
# CAR            30582
# Region IV-B    30849
# Region XI      32522
# Name: Dengue_Cases, dtype: int64

# %% [markdown]
# <h2>Insight 17: The top 5 region with the lowest dengue cases are the following in order: BARMM, Region V, CAR, Region IV-B, Region XI </h2>

# %% [markdown]
# <h1>Question 18: Which five regions have the highest dengue deaths</h1>

# %%
dengue_region = dengue.groupby('Region')['Dengue_Deaths'].sum().sort_values(ascending=False)
dengue_region.plot(kind='bar')
plt.xlabel('Region')
plt.ylabel('Dengue Deaths')
# Out:
# Text(0, 0.5, 'Dengue Deaths')

# %%
dengue_region = dengue.groupby('Region')['Dengue_Deaths'].sum().sort_values(ascending=False)
dengue_region.head()
# Out:
# Region
# NCR           4008
# Region XII    2796
# Region VI     1825
# Region VII    1760
# CAR           1008
# Name: Dengue_Deaths, dtype: int64

# %% [markdown]
# <h2>Insight 18: The top 5 region with the highest dengue deaths are the following in order: NCR, Region XII, Region VI, Region VII, CAR </h2>

# %% [markdown]
# <h1>Question 19: Which five regions have the lowest dengue deaths</h1>

# %%
dengue_region = dengue.groupby('Region')['Dengue_Deaths'].sum().sort_values(ascending=True)
dengue_region.plot(kind='bar')
plt.xlabel('Region')
plt.ylabel('Dengue Deaths')
# Out:
# Text(0, 0.5, 'Dengue Deaths')

# %%
dengue_region = dengue.groupby('Region')['Dengue_Deaths'].sum().sort_values(ascending=True)
dengue_region.head()
# Out:
# Region
# Region IV-B    130
# Region I       157
# Region V       185
# Region II      193
# BARMM          332
# Name: Dengue_Deaths, dtype: int64

# %% [markdown]
# <h2>Insight 19: The top 5 region with the lowest dengue deaths are the following in order: Region IV-B, Region I, Region V, Region II, BARMM</h2>

# %% [markdown]
# <h1>Question 20: Which five months has the highest dengue cases?</h1>

# %%
dengue_month = dengue.groupby('Month')['Dengue_Cases'].sum().sort_values(ascending=False)
dengue_month.plot(kind='bar')
plt.xlabel('Month')
plt.ylabel('Dengue Cases')
# Out:
# Text(0, 0.5, 'Dengue Cases')

# %% [markdown]
# <h2>Insight 20: The top 5 months with the highest dengue cases are the following in order: August, September, July, October, November</h2>

# %% [markdown]
# <h1>Question 21: Which five months has the lowest dengue cases?</h1>

# %%
dengue_month = dengue.groupby('Month')['Dengue_Cases'].sum().sort_values(ascending=True)
dengue_month.plot(kind='bar')
plt.xlabel('Month')
plt.ylabel('Dengue Cases')
# Out:
# Text(0, 0.5, 'Dengue Cases')

# %% [markdown]
# <h2>Insight 21: The top 5 months with the lowest dengue cases are the following in order: May, April, March, June, February</h2>

# %% [markdown]
# <h1>Question 22: Which five months has the highest dengue deaths?</h1>

# %%
dengue_month = dengue.groupby('Month')['Dengue_Deaths'].sum().sort_values(ascending=False)
dengue_month.plot(kind='bar')
plt.xlabel('Month')
plt.ylabel('Dengue Deaths')
# Out:
# Text(0, 0.5, 'Dengue Deaths')

# %% [markdown]
# <h2>Insight 22: The top 5 months with the highest dengue deaths are the following in order: October, September, August, November, July</h2>

# %% [markdown]
# <h1>Question 23: Which five months has the lowest dengue deaths?</h1>

# %%
dengue_month = dengue.groupby('Month')['Dengue_Deaths'].sum().sort_values(ascending=True)
dengue_month.plot(kind='bar')
plt.xlabel('Month')
plt.ylabel('Dengue Deaths')
# Out:
# Text(0, 0.5, 'Dengue Deaths')

# %% [markdown]
# <h2>Insight 23: The top 5 months with the lowest dengue deaths are the following in order: May, April, March, February, June</h2>
